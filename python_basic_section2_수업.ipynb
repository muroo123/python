# %% [markdown]
# <a href="https://colab.research.google.com/github/muroo123/python/blob/main/python_basic_section2_%EC%88%98%EC%97%85.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **수업 내용**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # SECTION2: 연산자

# %% [markdown]
# ## 2-1.산술연산자
# • Python 수학의 사칙연산 이외의 프로그래밍 연산자
# ![image.png](data:image/png;base64,...)

# %%
a = 7
b = 4
# Out:
# 7 +  4 = 11
# 7 -  4 = 3
# 7 *  4 = 28
# 7 /  4 = 1.75
# 7 // 4 = 1
# 7 %  4 = 3
# 7 ** 4 = 2401

# %%
# [1] 거듭제곱, 산술 연산자
a, b = 10, 3

# [1-1] a의 b승을 연산자와 함수를 사용하여 구해본다


# [1-2] a와 b의 사칙연산(+, -, *, /)를 실행해 본다
#       (나눗셈의 결과는 반올림하여 소수점아래 2개까지 표시)


# [1-3] a와 b를 나누어 그 몫, 나머지를 연산자와 함수를 사용해 구해본다
  # name unpack
# Out:
# 1000 1000
# 13 7 30 3.33
# 3 1 (3, 1) 3 1

# %%
# 산술연산자 우선 순위
# ** > *, /, //, % > +, -

# %%
# [2] (  )를 사용한 우선 순위 변경
#     b와 c를 더한 결과를 a와 곱한 결과 구하기
a, b, c = 10, 3, 1
# Out:
# 40

# %% [markdown]
# ## 2-2 할당 연산자
# ![image.png](data:image/png;base64,...)

# %%
# [2] 할당 연산자 (+=, -=, *=, /=, %=, **=, //=) : 결과는 산술연산과 동일
a = 4
c = 7

# [2-1] c = c + a 결과 출력


# [2-2]  c = c - a 결과 출력


# [2-3]  c = c * a 결과 출력


# [2-4]  c = c / a 결과 출력
c = 7


# [2-5]  c = c % a 결과 출력
c = 7


# [2-6]  c = c // a 결과 출력
c = 7


# [2-7]  c = c ** a 결과 출력
c = 7
# Out:
# 11
# 7
# 28
# 1.75
# 3
# 1
# 2401

# %% [markdown]
# ## 2-3 비교연산자
# • 값의 크기를 비교하는 연산자를 비교 연산자
#
# • 조건에 만족하는지를 확인하고 참과 거짓을 반환함
#
# ![image.png](data:image/png;base64,...)

# %%
# [3] 비교 연산자 (==, !=, >, <, >=, <=) : 결과는 True/False
a, b = 10, 5

# [3-1] a와 b가 같다, 다르다의 결과 출력


# [3-2] a가 b보다 크다(초과), 작다(미만)의 결과 출력


# [3-3] a가 b보다 크거나 같다(이상), 작거나 같다(이하)의 결과 출력


# [3-4] a가 5보다 크고, 15보다 작다 (and)
# Out:
# False True
# True False
# True False
# True True

# %% [markdown]
# ## 2-4 멤버연산자
# ![image.png](data:image/png;base64,...)

# %%
# [4] 컨테이너 자료형 내에 포함된 것인지 확인 (in) : 결과는 True/False

message = "  Python Easy "
# Out:
# True
# False
# True

# %% [markdown]
# ## 2-5 식별연산자
# ![image.png](data:image/png;base64,...)

# %%
# [5] a, b의 값 비교(==), 주소 비교(is),
#     포함된 것인지 확인 (in) : 결과는 True/False
a = 300
b = 300
print(id(a), id(b)) # 다른 객체이다
# Out:
# 140450610340080 140450610339888
# True False
# False True

# %% [markdown]
# ## 2-6 논리연산자
# ![image.png](data:image/png;base64,...)

# %%
# [6] 논리 연산자 (and, or, not)
a = True
b = False


a = 10
# [6-1] a가 정수이고, 10보다 크다


# [6-2] a가 정수이거나, 10보다 크다


# [6-3] a가 0이다
# not True => False, not False => True
# Out:
# False
# True
# True
# False
# True
# False False

# %%
# False/True 취급되는 객체
# False로 취급되는 객체 : 0, 0.0, False, None, '', "", (), [], {}, set()
# False가 아닌 객체들을 True로 취급

# %%
bool(0), bool(0.0), bool(None), bool(''), bool(()), bool([]), bool({}), bool(set())
# Out:
# (False, False, False, False, False, False, False, False)

# %%
bool(10), bool(3.14), bool([1, 2, 3])
# Out:
# (True, True, True)

# %% [markdown]
# ## 2-7 비트연산자
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2-7 비트 논리곱(&) 연산자
# ![image.png](data:image/png;base64,...)

# %%
# 비트 논리곱(&) 10&7

print(bin(10))
print(bin(7))
# Out:
# 0b1010
# 0b111
# 0b10
# 2

# %% [markdown]
# ### 2-7 비트 논리합(|) 연산자
# ![image.png](data:image/png;base64,...)

# %%
# 비트 논리합(|) 10|7

print(bin(10))
print(bin(7))
# Out:
# 0b1010
# 0b111
# 0b1111
# 15

# %% [markdown]
# ### 2-7 비트 배타적 논리합(^) 연산자
# - 각 자리의 두값이 다르면 1, 같으면 0
# ![image.png](data:image/png;base64,...)

# %%
# 비트 배타적 논리합(^) 10^7

print(bin(10))
print(bin(7))
# Out:
# 0b1010
# 0b111
# 0b1101
# 13

# %%
# 비트 부정(~) 연산자
# 1은 0, 0은 1로 바꿈
# 어떤 값의 반대 부호 값을 알고자 하는 경우

a = 10
# Out:
# 10 -10

# %% [markdown]
# ## 2-7 왼쪽 시프트(<<) 연산자
# - 나열된 비트를 지정된 길이 만큼 왼쪽으로 이동 (shift) 해주는 연산자
# -26 << 2
# ![image.png](data:image/png;base64,...)

# %%
# 왼쪽 시프트(<<)

a = 10
# Out:
# 10 20 40 80

# %% [markdown]
# ### 2-7 오른쪽 시프트(>>) 연산자
# - 나열된 비트를 지정된 길이 만큼 오른쪽으로 이동 (shift) 해주는 연산자
# - 26 >> 2
# ![image.png](data:image/png;base64,...)

# %%
# 오른쪽 시프트(>>)

a = 10
# Out:
# 10 5 2 1 0

# %%
#비트연산자 연습
a = 60
b = 13
# Out:
# 0b111100
# 0b1101
# 0b1100 12
# 0b111101 61
# 0b110001 49
# -0b111101 -61
# 0b11110000 240
# 0b1111 15

# %% [markdown]
# ## 2-8 연산자 활용

# %%
# [8] 연산자 활용 -1
# 다음 숫자에 대해 각각 1, 2, 3이 출력되도록 {} 내부에 식을 작성하여 보도록 한다
c = 123
# Out:
# 백의 자리 = 1, 십의 자리 = 2, 일의 자리 = 3

# %%
c = 123
c = str(c)  # 정수를 문자열로 형변환 '123'
print(type(c))
# Out:
# <class 'str'>
# 백의 자리 = 1, 십의 자리 = 2, 일의 자리 = 3
# 백의 자리 = 1, 십의 자리 = 2, 일의 자리 = 3

# %%
# [8] 연산자 활용 -2
# a의 값을 1 증가시켜 출력해 보자
a = 10
#a = a + 1
# Out:
# 11

# %%
# [8] Numeric type 끼리는 type이 달라도 연산 가능
# 표현 범위가 넓은 type의 결과를 생성함  float > int > bool
# int + float = float, int + bool = int, int / int = float
a = 10 + 3.14
b = 1 + True
c, d = 10, 3

# a, b의 결과와 객체 type은 무엇일까?
# Out:
# 13.14 <class 'float'>
# 2 <class 'int'>
# 3.3333333333333335 <class 'float'>

# %%
# [9] Container는 연산자 사용시 같은 type 끼리만 연산 가능
# str, tuple, list => +, *
# 필요시 container 형변환 list(b)
a = [1, 2, 3]
b = (4, 5)
# Out:
# [1, 2, 3, 4, 5] [1, 2, 3, 1, 2, 3, 1, 2, 3]
